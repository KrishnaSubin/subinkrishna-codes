# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\data.csv")

# %%
df
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      38   technician   married   tertiary      no      127     yes   no
# 1      41    housemaid   married    primary      no      365      no   no
# 2      39   management    single   tertiary      no     2454     yes   no
# 3      49  blue-collar   married    primary      no     6215     yes   no
# 4      37     services   married  secondary      no     1694     yes  yes
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 8366   52   management   married   tertiary      no      388      no   no
# 8367   39     services   married  secondary      no     2758      no   no
# 8368   38  blue-collar   married    primary      no      178     yes   no
# 8369   59      retired  divorced    unknown      no      -49     yes   no
# 8370   41  blue-collar  divorced    primary      no        0      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.tail()
# Out:
#       age          job   marital  education default  balance housing loan  \
# 8366   52   management   married   tertiary      no      388      no   no
# 8367   39     services   married  secondary      no     2758      no   no
# 8368   38  blue-collar   married    primary      no      178     yes   no
# 8369   59      retired  divorced    unknown      no      -49     yes   no
# 8370   41  blue-collar  divorced    primary      no        0      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 8366  cellular   25   may       272         1     -1         0  unknown
# 8367  cellular    4   feb       658         3     -1         0  unknown
# 8368   unknown   20   may       245         1     -1         0  unknown
# 8369   unknown   13   may       248         2     -1         0  unknown
# 8370  cellular   30   jul       509         2     -1         0  unknown
#
#      deposit
# 8366     yes
# 8367     yes
# 8368      no
# 8369      no
# 8370     yes

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  8371.000000   8371.000000  8371.000000  8371.000000  8371.000000
# mean     41.197467   1517.811134    15.588460   372.898698     2.512603
# std      11.809300   3225.312218     8.406768   346.706743     2.734037
# min      18.000000  -3058.000000     1.000000     2.000000     1.000000
# 25%      32.000000    116.000000     8.000000   137.000000     1.000000
# 50%      39.000000    532.000000    15.000000   255.000000     2.000000
# 75%      49.000000   1694.000000    21.000000   504.000000     3.000000
# max      95.000000  81204.000000    31.000000  3284.000000    63.000000
#
#              pdays     previous
# count  8371.000000  8371.000000
# mean     49.911958     0.823677
# std     107.308417     2.315285
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%       2.000000     1.000000
# max     854.000000    58.000000

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
df.drop(labels="duration",axis=1,inplace=True)
df.drop(labels="default",axis=1,inplace=True)
df.drop(labels="day",axis=1,inplace=True)
df.drop(labels="contact",axis=1,inplace=True)
df.drop(labels="housing",axis=1,inplace=True)

# %%
df.hist(figsize=(12,8),bins=20)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['balance','campaign','pdays','previous']]=scaler.fit_transform(df[['balance','campaign','pdays','previous']])

# %%
df
# Out:
#       age          job   marital  education   balance loan month  campaign  \
# 0      38   technician   married   tertiary  0.037799   no   oct  0.000000
# 1      41    housemaid   married    primary  0.040623   no   aug  0.064516
# 2      39   management    single   tertiary  0.065415   no   may  0.032258
# 3      49  blue-collar   married    primary  0.110050   no   may  0.000000
# 4      37     services   married  secondary  0.056396  yes   jan  0.016129
# ...   ...          ...       ...        ...       ...  ...   ...       ...
# 8366   52   management   married   tertiary  0.040896   no   may  0.000000
# 8367   39     services   married  secondary  0.069023   no   feb  0.032258
# 8368   38  blue-collar   married    primary  0.038404   no   may  0.000000
# 8369   59      retired  divorced    unknown  0.035710   no   may  0.016129
# 8370   41  blue-collar  divorced    primary  0.036292   no   jul  0.016129
#
#          pdays  previous poutcome deposit
# ...

# %%
from sklearn import preprocessing

# %%
label = preprocessing.LabelEncoder()
df[ 'job' ]= label.fit_transform(df[ 'job' ])   
df[ 'marital' ]= label.fit_transform(df[ 'marital' ])
df[ 'education' ]= label.fit_transform(df[ 'education' ])
df[ 'loan' ]= label.fit_transform(df[ 'loan' ])
df[ 'month' ]=label.fit_transform(df[ 'month' ])
df[ 'poutcome' ]= label.fit_transform(df[ 'poutcome' ])
df[ 'deposit' ]= label.fit_transform(df[ 'deposit' ])

# %%
df
# Out:
#       age  job  marital  education   balance  loan  month  campaign     pdays  \
# 0      38    9        1          2  0.037799     0     10  0.000000  0.059649
# 1      41    3        1          0  0.040623     0      1  0.064516  0.000000
# 2      39    4        2          2  0.065415     0      8  0.032258  0.308772
# 3      49    1        1          0  0.110050     0      8  0.000000  0.000000
# 4      37    7        1          1  0.056396     1      4  0.016129  0.294737
# ...   ...  ...      ...        ...       ...   ...    ...       ...       ...
# 8366   52    4        1          2  0.040896     0      8  0.000000  0.000000
# 8367   39    7        1          1  0.069023     0      3  0.032258  0.000000
# 8368   38    1        1          0  0.038404     0      8  0.000000  0.000000
# 8369   59    5        0          3  0.035710     0      8  0.016129  0.000000
# 8370   41    1        0          0  0.036292     0      5  0.016129  0.000000
#
# ...

# %%
plt.figure(figsize=(10,11))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
plt.plot()
# Out:
# []

# %%
X=df.drop(labels="deposit",axis=1)
y=df['deposit']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.30,random_state = 101)

# %% [markdown]
# # Decision tree classifer

# %%
from sklearn.tree import DecisionTreeClassifier  
classifier= DecisionTreeClassifier(criterion='entropy', random_state=0)  
classifier.fit(X_train, y_train)
pred=classifier.predict(X_test)

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pred))
recall_bc=recall_score(y_test, pred, average='macro')
print("recall= ",recall_bc)

classi_bc=f1_score(y_test, pred)
print("f1 score= ",classi_bc)

precision_bc=precision_score(y_test, pred, average='macro')
print("precision= ",precision_bc)
# Out:
# 0.6007165605095541
# recall=  0.600623835269392
# f1 score=  0.5897750511247444
# precision=  0.6004742341245688

# %% [markdown]
# # Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None)
classifier.fit(X_train, y_train)
pred=classifier.predict(X_test)
print(accuracy_score(y_test,pred))

recall_bc=recall_score(y_test, pred, average='macro')
print("recall= ",recall_bc)

classi_bc=f1_score(y_test, pred)
print("f1 score= ",classi_bc)

precision_bc=precision_score(y_test, pred, average='macro')
print("precision= ",precision_bc)
# Out:
# 0.6007165605095541
# recall=  0.600623835269392
# f1 score=  0.5897750511247444
# precision=  0.6004742341245688

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0)
lr.fit(X_train, y_train)
pred=lr.predict(X_test)
print(accuracy_score(y_test,pred))

recall_bc=recall_score(y_test, pred, average='macro')
print("recall= ",recall_bc)

classi_bc=f1_score(y_test, pred)
print("f1 score= ",classi_bc)

precision_bc=precision_score(y_test, pred, average='macro')
print("precision= ",precision_bc)
# Out:
# 0.5987261146496815
# recall=  0.5933679802658522
# f1 score=  0.5245283018867926
# precision=  0.6006316488224164
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
eclf2= BaggingClassifier(base_estimator=DecisionTreeClassifier()).fit(X_train, y_train)
var1=eclf2.predict(X_test)

recall_bc=recall_score(y_test, var1, average='macro')
print("recall= ",recall_bc)

classi_bc=f1_score(y_test, var1)
print("f1 score= ",classi_bc)

precision_bc=precision_score(y_test, var1, average='macro')
print("precision= ",precision_bc)
# Out:
# recall=  0.6547870229565029
# f1 score=  0.6055299539170506
# precision=  0.6632975071256083

# %%
# The precision, recall and f1 score ogf bagging classifier is higher than other machine learning models.

# %%
# loadind test datas

# %%
b = pd.read_csv(r"C:\Users\HP\Downloads\test_data.csv")

# %%
b
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      31    blue-collar    single  secondary     yes      477      no   no
# 1      49    blue-collar   married    primary      no      599      no   no
# 2      51  self-employed    single   tertiary      no      400      no  yes
# 3      33     technician   married  secondary      no      488     yes   no
# 4      34         admin.   married  secondary      no       40     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 2786   44     management    single   tertiary     yes       12     yes   no
# 2787   37     management    single   tertiary      no       33     yes   no
# 2788   42         admin.  divorced  secondary      no      936      no   no
# 2789   38        student    single    unknown      no       64      no   no
# 2790   29         admin.   married   tertiary      no      332      no   no
#
# ...

# %%
b.describe()
# Out:
#               age       balance          day     duration     campaign  \
# count  2791.00000   2791.000000  2791.000000  2791.000000  2791.000000
# mean     41.33823   1560.735937    15.868506   369.279828     2.495880
# std      12.22033   3226.072210     8.459618   348.438131     2.686332
# min      18.00000  -6847.000000     1.000000     5.000000     1.000000
# 25%      32.00000    136.000000     8.000000   143.500000     1.000000
# 50%      39.00000    596.000000    16.000000   254.000000     2.000000
# 75%      49.00000   1764.000000    22.000000   475.000000     3.000000
# max      93.00000  81204.000000    31.000000  3881.000000    43.000000
#
#              pdays     previous
# count  2791.000000  2791.000000
# mean     55.584737     0.859190
# std     112.908209     2.220922
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      81.000000     1.000000
# max     804.000000    37.000000

# %%
b.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
b.drop(labels="duration",axis=1,inplace=True)
b.drop(labels="default",axis=1,inplace=True)
b.drop(labels="day",axis=1,inplace=True)
b.drop(labels="contact",axis=1,inplace=True)
b.drop(labels="housing",axis=1,inplace=True)

# %%
label = preprocessing.LabelEncoder()
b[ 'job' ]= label.fit_transform(b[ 'job' ])   
b[ 'marital' ]= label.fit_transform(b[ 'marital' ])
b[ 'education' ]= label.fit_transform(b[ 'education' ])
b[ 'loan' ]= label.fit_transform(b[ 'loan' ])
b[ 'month' ]=label.fit_transform(b[ 'month' ])
b[ 'poutcome' ]= label.fit_transform(b[ 'poutcome' ])

# %%
print(pred)
# Out:
# [1 1 0 ... 0 0 0]

# %%
eclf2= BaggingClassifier(base_estimator=DecisionTreeClassifier()).fit(X_train, y_train)
pred=lr.predict(b)
print(pred)
# Out:
# [1 1 1 ... 1 1 1]

# %%
result_df = pd.DataFrame(pred, columns =["Prediction"])

# %%
result_df.to_csv(r"C:\Users\HP\Downloads\result.csv")
